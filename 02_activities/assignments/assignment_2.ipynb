# %% [markdown]
# # Practice Interview
#
# ## Objective
#
# _*The partner assignment aims to provide participants with the opportunity to practice coding in an interview context. You will analyze your partner's Assignment 1. Moreover, code reviews are common practice in a software development team. This assignment should give you a taste of the code review process.*_
#
# ## Group Size
#
# Each group should have 2 people. You will be assigned a partner
#
# ## Parts:
# - Part 1: Complete 1 of 3 questions
# - Part 2: Review your partner's Assignment 1 submission
# - Part 3: Perform code review of your partner's assignment 1 by answering the questions below
# - Part 3: Reflect on Assignment 1 and Assignment 2
#
# ## Part 1:
#
# _*You will be assigned one of three problems based of your first name. Enter your first name, in all lower case, execute the code below, and that will tell you your assigned problem. Include the output as part of your submission (do not clear the output). The problems are based-off problems from Leetcode.*_

# %%
import hashlib

def hash_to_range(input_string: str) -> int:
     hash_object = hashlib.sha256(input_string.encode())
     hash_int = int(hash_object.hexdigest(), 16)
     return (hash_int % 3) + 1
input_string = "ajinkya"
result = hash_to_range(input_string)
print(result)
# Out:
# 1

# %% [markdown]
# <details>
#   <summary>Question 1</summary>
#
#   # Question One: Check Duplicates in Tree
#
#   Given the `root` of a binary tree, check whether it is contains a duplicate value. If a duplicate exists, return the duplicate value. If there are multiple duplicates, return the one with the closest distance to the root. If no duplicate exists, return -1.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?* (Breadth First Traversal)
#
#   Output: 2
#
#   ### Example 2
#
#   ![](./images/q1_ex2.png)
#
#   Input: `root = [1, 10, 2, 3, 10, 12, 12]`
#
#   Output: 10
#
#   ### Example 3
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 8, 7]`
#
#   Output: -1
#
# </details>
#
# #### Starter Code for Question 1

# %%
# Definition for a binary tree node.
from collections import deque
from typing import Optional,List

class TreeNode(object):
    def __init__(self, val = 0, left = None, right = None):
        self.val = val
        self.left = left
        self.right = right
def build_tree_level_order(values: List[Optional[int]]) -> Optional[TreeNode]:
    if not values:
        return None
    it = iter(values)
    root_val = next(it)
    if root_val is None:
        return None
    root = TreeNode(root_val)
    queue = deque([root])
    for val in it:
        node = queue.popleft()
        left_val = val
        if left_val is not None:
            node.left = TreeNode(left_val)
            queue.append(node.left)
        try:
            right_val = next(it)
        except StopIteration:
            break
        if right_val is not None:
            node.right = TreeNode(right_val)
            queue.append(node.right)
    return root

def is_duplicate(root: Optional[TreeNode]) -> int:
    if not root:
        return -1
    
    seen = set()
    queue = deque([root])
    
    while queue:
        node = queue.popleft()
        if node.val in seen:
            return node.val
        seen.add(node.val)
        if node.left:
            queue.append(node.left)
        if node.right:
            queue.append(node.right)
    
    return -1

# Example usage:
# Constructing a binary tree with duplicate values
root = build_tree_level_order([1, 2, 2, 3, 5, 6, 7])
result = is_duplicate(root)
print(result)  # Output: 2
# Out:
# 2

# %% [markdown]
# <details>
#   <summary>Question 2</summary>
#
#   # Question Two: Path to Leaves
#
#   Given the `root` of a binary tree, return all root to leaf paths in any order.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?*
#
#   Output: [[1, 2, 3], [1, 2, 5], [1, 2, 6], [1, 2, 7]]
#
#   ### Example 2
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 7, 8]`
#
#   Output: [[10, 7], [10, 9, 8]]
#
# </details>
#
# #### Starter Code for Question 2

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val = 0, left = None, right = None):
#         self.val = val
#         self.left = left
#         self.right = right
def bt_path(root: TreeNode) -> List[List[int]]:
  # TODO

# %% [markdown]
# <details>
#   <summary>Question 3</summary>
#
#   # Question Three: Missing Number in Range
#
#   You are given a list containing `n` integers in the range `[0, n]`. Return a list of numbers that are missing from the range `[0, n]` of the array. If there is no missing number, return -1. Note, all the integers in the list may not be unique.
#
#   ## Examples
#
#   ### Example 1
#
#   Input: `lst = [0, 2]`
#
#   Output: [1]
#
#   ### Example 2
#
#   Input: `lst = [5, 0, 1]`
#
#   Output: [2, 3, 4]
#
#   ### Example 3
#
#   Input: `lst = [6, 8, 2, 3, 5, 7, 0, 1, 10]`
#
#   Output: [4, 9]
#
# </details>
#
# #### Starter Code for Question 3

# %%
def missing_num(nums: List) -> int:
  # TODO

# %% [markdown]
# ## Part 2:
#
# You and your partner must share each other's Assignment 1 submission.

# %% [markdown]
# ## Part 3:
#
# Create a Jupyter Notebook, create 6 of the following headings, and complete the following for your partner's assignment 1:
#
# -   Paraphrase the problem in your own words.

# %%
# Your answer here
print("We need to check whether a string of (), {}, and [] is properly balanced and nested so that every opener is closed by the same type, in last-opened-first-closed order.")
# Out:
# We need to check whether a string of (), {}, and [] is properly balanced and nested so that every opener is closed by the same type, in last-opened-first-closed order.

# %% [markdown]
# -   Create 1 new example that demonstrates you understand the problem. Trace/walkthrough 1 example that your partner made and explain it.

# %%
"""New example:
Input: s = "([{}])[]"
Output: True
Reason: The brackets are properly nested and each opener is closed by the same type.

Walkthrough (using "([)]" as a mismatch case):
- Read '(': stack = ['(']
- Read '[': stack = ['(', '[']
- Read ')': top of stack is '[' so this is a mismatch -> invalid (False)
"""
# Out:
# 'New example:\nInput: s = "([{}])[]"\nOutput: True\nReason: The brackets are properly nested and each opener is closed by the same type.\n\nWalkthrough (using "([)]" as a mismatch case):\n- Read \'(\': stack = [\'(\']\n- Read \'[\': stack = [\'(\', \'[\']\n- Read \')\': top of stack is \'[\' so this is a mismatch -> invalid (False)\n'

# %% [markdown]
# -   Copy the solution your partner wrote.

# %%
# Your answer here
def is_valid_brackets(s: str) -> bool:
    
    # Stack to keep track of opening brackets
    stack = []
    
    # Mapping of closing brackets to their corresponding opening brackets
    bracket_map = {
        ')': '(',
        '}': '{',
        ']': '['
    }
    
    # for each character in the string
    for char in s:
        # If it's a closing bracket
        if char in bracket_map:
            # Check if stack is empty 
            # or if top of stack doesn't match the expected opening bracket
            if not stack or stack[-1] != bracket_map[char]:
                return False
            # Pop the matching opening bracket from stack
            stack.pop()
        else:
            # if it's an opening bracket, push to stack
            stack.append(char)
    
    # Valid only if all brackets were matched (stack is empty)
    return len(stack) == 0

# %% [markdown]
# -   Explain why their solution works in your own words.

# %%
# Your answer here
"""This works because it enforces the two validity rules using a stack (LIFO):

Every opener is pushed, so the last unmatched opener is always on top.
When a closer appears, it must match the top; otherwise the order or type is wrong, so return False.
If any closer shows up when the stack is empty, there’s no opener to match, so False.
At the end, the stack must be empty; leftover openers mean not all were closed."""
# Out:
# 'This works because it enforces the two validity rules using a stack (LIFO):\n\nEvery opener is pushed, so the last unmatched opener is always on top.\nWhen a closer appears, it must match the top; otherwise the order or type is wrong, so return False.\nIf any closer shows up when the stack is empty, there’s no opener to match, so False.\nAt the end, the stack must be empty; leftover openers mean not all were closed.'

# %% [markdown]
# -   Explain the problem’s time and space complexity in your own words.

# %%
# Your answer here
"""Time complexity is O(n) because we scan the string once and each bracket is pushed/popped at most one time. Space complexity is O(n) in the worst case because the stack can hold all opening brackets if the string is like "((([[{"."""
# Out:
# 'Time complexity is O(n) because we scan the string once and each bracket is pushed/popped at most one time. Space complexity is O(n) in the worst case because the stack can hold all opening brackets if the string is like "((([[{".'

# %% [markdown]
# -   Critique your partner's solution, including explanation, and if there is anything that should be adjusted.

# %%
"""
- The stack approach is correct and efficiently enforces proper nesting and matching.
- The code is clear and uses a clean map for bracket pairs.
- Minor improvement: validate or ignore unexpected characters if inputs may include other symbols (currently treats them as openers).
- Add a few edge-case tests (empty string, single opener, single closer) to show behavior.
"""
# Out:
# '\n- The stack approach is correct and efficiently enforces proper nesting and matching.\n- The code is clear and uses a clean map for bracket pairs.\n- Minor improvement: validate or ignore unexpected characters if inputs may include other symbols (currently treats them as openers).\n- Add a few edge-case tests (empty string, single opener, single closer) to show behavior.\n'

# %% [markdown]
# ## Part 4:
#
# Please write a 200 word reflection documenting your process from assignment 1, and your presentation and review experience with your partner at the bottom of the Jupyter Notebook under a new heading "Reflection." Again, export this Notebook as pdf.

# %% [markdown]
# ### Reflection

# %%
"""Reflection

In Assignment 1, I started by rewriting each problem in my own words and listing the input, output, and edge cases before touching code. That helped me avoid jumping into an approach that would miss constraints. I sketched a simple plan for each problem (data structure choice, traversal order, and termination conditions) and then wrote a small, testable version first. I used a few manual examples to validate behavior and only then cleaned up naming and added comments. The biggest improvement was catching off-by-one errors early by tracing one full example on paper.

For the presentation, I focused on explaining the “why” behind my approach rather than only showing the final code. I walked through a sample input step by step and tried to keep my reasoning explicit. In the review with my partner, I learned how important it is to state assumptions (like input validity) and to check for edge cases like empty inputs or single elements. Giving feedback made me notice where explanations could be clearer even if the code was correct. Overall, the peer review reinforced good habits: clarity, small tests, and justification for choices. I feel more confident in both solving and explaining algorithmic problems.
"""

# %% [markdown]
# ## Evaluation Criteria
#
# We are looking for the similar points as Assignment 1
#
# -   Problem is accurately stated
#
# -   New example is correct and easily understandable
#
# -   Correctness, time, and space complexity of the coding solution
#
# -   Clarity in explaining why the solution works, its time and space complexity
#
# -   Quality of critique of your partner's assignment, if necessary

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-2`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_2.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/algorithms_and_data_structures/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-6-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
